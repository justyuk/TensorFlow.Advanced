# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1152        input_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          16512       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dense_4[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_4[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_5[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 262.5046 - y1_output_loss: 122.0486 - y2_output_loss: 138.2045 - y1_output_root_mean_squared_error: 11.0977 - y2_output_root_mean_squared_error: 11.8045 - val_loss: 45.1064 - val_y1_output_loss: 17.1815 - val_y2_output_loss: 26.7593 - val_y1_output_root_mean_squared_error: 4.2003 - val_y2_output_root_mean_squared_error: 5.2406
# Epoch 2/500
# 614/614 [==============================] - 0s 158us/sample - loss: 36.3570 - y1_output_loss: 14.1127 - y2_output_loss: 22.2292 - y1_output_root_mean_squared_error: 3.7485 - y2_output_root_mean_squared_error: 4.7229 - val_loss: 41.2948 - val_y1_output_loss: 13.5342 - val_y2_output_loss: 26.4982 - val_y1_output_root_mean_squared_error: 3.7399 - val_y2_output_root_mean_squared_error: 5.2257
# Epoch 3/500
# 614/614 [==============================] - 0s 157us/sample - loss: 28.6155 - y1_output_loss: 10.7421 - y2_output_loss: 17.8015 - y1_output_root_mean_squared_error: 3.2692 - y2_output_root_mean_squared_error: 4.2341 - val_loss: 21.9772 - val_y1_output_loss: 9.3117 - val_y2_output_loss: 11.9818 - val_y1_output_root_mean_squared_error: 3.1034 - val_y2_output_root_mean_squared_error: 3.5137
# Epoch 4/500
# 614/614 [==============================] - 0s 146us/sample - loss: 27.1307 - y1_output_loss: 10.2365 - y2_output_loss: 17.1594 - y1_output_root_mean_squared_error: 3.1813 - y2_output_root_mean_squared_error: 4.1243 - val_loss: 36.1954 - val_y1_output_loss: 8.8988 - val_y2_output_loss: 26.3952 - val_y1_output_root_mean_squared_error: 3.0264 - val_y2_output_root_mean_squared_error: 5.1996
# Epoch 5/500
# 614/614 [==============================] - 0s 162us/sample - loss: 25.4757 - y1_output_loss: 9.7693 - y2_output_loss: 15.7311 - y1_output_root_mean_squared_error: 3.1188 - y2_output_root_mean_squared_error: 3.9685 - val_loss: 42.9374 - val_y1_output_loss: 12.2342 - val_y2_output_loss: 29.3966 - val_y1_output_root_mean_squared_error: 3.5579 - val_y2_output_root_mean_squared_error: 5.5026
# Epoch 6/500
# 614/614 [==============================] - 0s 142us/sample - loss: 30.8295 - y1_output_loss: 11.0118 - y2_output_loss: 19.7346 - y1_output_root_mean_squared_error: 3.3117 - y2_output_root_mean_squared_error: 4.4567 - val_loss: 18.9657 - val_y1_output_loss: 8.1170 - val_y2_output_loss: 10.3352 - val_y1_output_root_mean_squared_error: 2.8937 - val_y2_output_root_mean_squared_error: 3.2546
# Epoch 7/500
# 614/614 [==============================] - 0s 144us/sample - loss: 28.2828 - y1_output_loss: 10.3158 - y2_output_loss: 17.7564 - y1_output_root_mean_squared_error: 3.2238 - y2_output_root_mean_squared_error: 4.2296 - val_loss: 14.7685 - val_y1_output_loss: 5.9888 - val_y2_output_loss: 8.3809 - val_y1_output_root_mean_squared_error: 2.4851 - val_y2_output_root_mean_squared_error: 2.9314
# Epoch 8/500
# 614/614 [==============================] - 0s 141us/sample - loss: 20.2741 - y1_output_loss: 8.2149 - y2_output_loss: 11.9060 - y1_output_root_mean_squared_error: 2.8765 - y2_output_root_mean_squared_error: 3.4640 - val_loss: 14.4681 - val_y1_output_loss: 6.1408 - val_y2_output_loss: 7.9336 - val_y1_output_root_mean_squared_error: 2.5165 - val_y2_output_root_mean_squared_error: 2.8522
# Epoch 9/500
# 614/614 [==============================] - 0s 140us/sample - loss: 21.1562 - y1_output_loss: 8.3512 - y2_output_loss: 13.0491 - y1_output_root_mean_squared_error: 2.8737 - y2_output_root_mean_squared_error: 3.5914 - val_loss: 17.5368 - val_y1_output_loss: 7.2000 - val_y2_output_loss: 9.9052 - val_y1_output_root_mean_squared_error: 2.7213 - val_y2_output_root_mean_squared_error: 3.1830
# Epoch 10/500
# 614/614 [==============================] - 0s 140us/sample - loss: 21.0895 - y1_output_loss: 8.3936 - y2_output_loss: 12.8171 - y1_output_root_mean_squared_error: 2.9020 - y2_output_root_mean_squared_error: 3.5592 - val_loss: 37.6569 - val_y1_output_loss: 9.9519 - val_y2_output_loss: 26.4350 - val_y1_output_root_mean_squared_error: 3.2088 - val_y2_output_root_mean_squared_error: 5.2307
# Epoch 11/500
# 614/614 [==============================] - 0s 147us/sample - loss: 25.4878 - y1_output_loss: 9.2319 - y2_output_loss: 16.6466 - y1_output_root_mean_squared_error: 3.0292 - y2_output_root_mean_squared_error: 4.0388 - val_loss: 17.5469 - val_y1_output_loss: 7.2242 - val_y2_output_loss: 9.9585 - val_y1_output_root_mean_squared_error: 2.7225 - val_y2_output_root_mean_squared_error: 3.1835
# Epoch 12/500
# 614/614 [==============================] - 0s 141us/sample - loss: 20.0717 - y1_output_loss: 7.9330 - y2_output_loss: 12.4551 - y1_output_root_mean_squared_error: 2.7855 - y2_output_root_mean_squared_error: 3.5090 - val_loss: 25.2318 - val_y1_output_loss: 9.5955 - val_y2_output_loss: 14.9556 - val_y1_output_root_mean_squared_error: 3.1407 - val_y2_output_root_mean_squared_error: 3.9202
# Epoch 13/500
# 614/614 [==============================] - 0s 140us/sample - loss: 23.7681 - y1_output_loss: 8.1866 - y2_output_loss: 15.4101 - y1_output_root_mean_squared_error: 2.8696 - y2_output_root_mean_squared_error: 3.9413 - val_loss: 15.8578 - val_y1_output_loss: 5.6959 - val_y2_output_loss: 9.7781 - val_y1_output_root_mean_squared_error: 2.4229 - val_y2_output_root_mean_squared_error: 3.1603
# Epoch 14/500
# 614/614 [==============================] - 0s 155us/sample - loss: 19.3758 - y1_output_loss: 7.5570 - y2_output_loss: 11.8123 - y1_output_root_mean_squared_error: 2.7528 - y2_output_root_mean_squared_error: 3.4348 - val_loss: 27.3616 - val_y1_output_loss: 9.6178 - val_y2_output_loss: 17.0200 - val_y1_output_root_mean_squared_error: 3.1380 - val_y2_output_root_mean_squared_error: 4.1850
# Epoch 15/500
# 614/614 [==============================] - 0s 146us/sample - loss: 18.6736 - y1_output_loss: 7.3942 - y2_output_loss: 11.1659 - y1_output_root_mean_squared_error: 2.7239 - y2_output_root_mean_squared_error: 3.3547 - val_loss: 15.0095 - val_y1_output_loss: 7.1642 - val_y2_output_loss: 7.4260 - val_y1_output_root_mean_squared_error: 2.7200 - val_y2_output_root_mean_squared_error: 2.7588
# Epoch 16/500
# 614/614 [==============================] - 0s 139us/sample - loss: 18.7086 - y1_output_loss: 6.8816 - y2_output_loss: 11.7762 - y1_output_root_mean_squared_error: 2.6268 - y2_output_root_mean_squared_error: 3.4364 - val_loss: 15.4162 - val_y1_output_loss: 6.0565 - val_y2_output_loss: 9.0040 - val_y1_output_root_mean_squared_error: 2.4939 - val_y2_output_root_mean_squared_error: 3.0326
# Epoch 17/500
# 614/614 [==============================] - 0s 142us/sample - loss: 18.4665 - y1_output_loss: 6.7962 - y2_output_loss: 11.5510 - y1_output_root_mean_squared_error: 2.6122 - y2_output_root_mean_squared_error: 3.4122 - val_loss: 15.7504 - val_y1_output_loss: 6.2531 - val_y2_output_loss: 9.0520 - val_y1_output_root_mean_squared_error: 2.5373 - val_y2_output_root_mean_squared_error: 3.0516
# Epoch 18/500
# 614/614 [==============================] - 0s 140us/sample - loss: 20.0545 - y1_output_loss: 7.3479 - y2_output_loss: 12.6009 - y1_output_root_mean_squared_error: 2.7195 - y2_output_root_mean_squared_error: 3.5579 - val_loss: 13.5768 - val_y1_output_loss: 4.7328 - val_y2_output_loss: 8.4865 - val_y1_output_root_mean_squared_error: 2.2095 - val_y2_output_root_mean_squared_error: 2.9487
# Epoch 19/500
# 614/614 [==============================] - 0s 142us/sample - loss: 17.0825 - y1_output_loss: 6.3932 - y2_output_loss: 10.5534 - y1_output_root_mean_squared_error: 2.5400 - y2_output_root_mean_squared_error: 3.2605 - val_loss: 10.7561 - val_y1_output_loss: 4.4523 - val_y2_output_loss: 6.0126 - val_y1_output_root_mean_squared_error: 2.1411 - val_y2_output_root_mean_squared_error: 2.4843
# Epoch 20/500
# 614/614 [==============================] - 0s 142us/sample - loss: 13.9426 - y1_output_loss: 5.4420 - y2_output_loss: 8.4212 - y1_output_root_mean_squared_error: 2.3421 - y2_output_root_mean_squared_error: 2.9082 - val_loss: 10.6610 - val_y1_output_loss: 4.0672 - val_y2_output_loss: 6.3330 - val_y1_output_root_mean_squared_error: 2.0459 - val_y2_output_root_mean_squared_error: 2.5446
# Epoch 21/500
# 614/614 [==============================] - 0s 146us/sample - loss: 14.5893 - y1_output_loss: 5.4531 - y2_output_loss: 9.0135 - y1_output_root_mean_squared_error: 2.3442 - y2_output_root_mean_squared_error: 3.0156 - val_loss: 10.1617 - val_y1_output_loss: 4.1590 - val_y2_output_loss: 5.7523 - val_y1_output_root_mean_squared_error: 2.0687 - val_y2_output_root_mean_squared_error: 2.4253
# Epoch 22/500
# 614/614 [==============================] - 0s 139us/sample - loss: 13.9512 - y1_output_loss: 5.2497 - y2_output_loss: 8.8602 - y1_output_root_mean_squared_error: 2.2896 - y2_output_root_mean_squared_error: 2.9511 - val_loss: 31.5462 - val_y1_output_loss: 7.4816 - val_y2_output_loss: 23.0370 - val_y1_output_root_mean_squared_error: 2.7801 - val_y2_output_root_mean_squared_error: 4.8803
# Epoch 23/500
# 614/614 [==============================] - 0s 143us/sample - loss: 13.7447 - y1_output_loss: 5.2844 - y2_output_loss: 8.6264 - y1_output_root_mean_squared_error: 2.2662 - y2_output_root_mean_squared_error: 2.9341 - val_loss: 33.1511 - val_y1_output_loss: 8.6950 - val_y2_output_loss: 23.5167 - val_y1_output_root_mean_squared_error: 2.9962 - val_y2_output_root_mean_squared_error: 4.9167
# Epoch 24/500
# 614/614 [==============================] - 0s 152us/sample - loss: 13.9247 - y1_output_loss: 5.1486 - y2_output_loss: 8.8781 - y1_output_root_mean_squared_error: 2.2541 - y2_output_root_mean_squared_error: 2.9738 - val_loss: 30.0674 - val_y1_output_loss: 9.0913 - val_y2_output_loss: 19.9989 - val_y1_output_root_mean_squared_error: 3.0683 - val_y2_output_root_mean_squared_error: 4.5446
# Epoch 25/500
# 614/614 [==============================] - 0s 140us/sample - loss: 14.2653 - y1_output_loss: 4.8448 - y2_output_loss: 9.4585 - y1_output_root_mean_squared_error: 2.1865 - y2_output_root_mean_squared_error: 3.0797 - val_loss: 11.5857 - val_y1_output_loss: 5.5499 - val_y2_output_loss: 5.6598 - val_y1_output_root_mean_squared_error: 2.3947 - val_y2_output_root_mean_squared_error: 2.4189
# Epoch 26/500
# 614/614 [==============================] - 0s 142us/sample - loss: 11.8388 - y1_output_loss: 4.4331 - y2_output_loss: 7.3585 - y1_output_root_mean_squared_error: 2.1113 - y2_output_root_mean_squared_error: 2.7169 - val_loss: 9.3315 - val_y1_output_loss: 3.8403 - val_y2_output_loss: 5.2231 - val_y1_output_root_mean_squared_error: 1.9878 - val_y2_output_root_mean_squared_error: 2.3195
# Epoch 27/500
# 614/614 [==============================] - 0s 146us/sample - loss: 13.0525 - y1_output_loss: 4.5650 - y2_output_loss: 8.4242 - y1_output_root_mean_squared_error: 2.1434 - y2_output_root_mean_squared_error: 2.9083 - val_loss: 12.8744 - val_y1_output_loss: 4.3489 - val_y2_output_loss: 8.0997 - val_y1_output_root_mean_squared_error: 2.1189 - val_y2_output_root_mean_squared_error: 2.8956
# Epoch 28/500
# 614/614 [==============================] - 0s 145us/sample - loss: 12.3750 - y1_output_loss: 4.4722 - y2_output_loss: 7.8650 - y1_output_root_mean_squared_error: 2.1208 - y2_output_root_mean_squared_error: 2.8067 - val_loss: 12.4762 - val_y1_output_loss: 4.3807 - val_y2_output_loss: 7.6735 - val_y1_output_root_mean_squared_error: 2.1295 - val_y2_output_root_mean_squared_error: 2.8180
# Epoch 29/500
# 614/614 [==============================] - 0s 146us/sample - loss: 9.5850 - y1_output_loss: 3.5962 - y2_output_loss: 5.9848 - y1_output_root_mean_squared_error: 1.8895 - y2_output_root_mean_squared_error: 2.4525 - val_loss: 16.9258 - val_y1_output_loss: 6.4448 - val_y2_output_loss: 9.9835 - val_y1_output_root_mean_squared_error: 2.5807 - val_y2_output_root_mean_squared_error: 3.2040
# Epoch 30/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.7456 - y1_output_loss: 3.7065 - y2_output_loss: 6.9861 - y1_output_root_mean_squared_error: 1.9334 - y2_output_root_mean_squared_error: 2.6472 - val_loss: 9.3648 - val_y1_output_loss: 3.1757 - val_y2_output_loss: 5.8976 - val_y1_output_root_mean_squared_error: 1.8098 - val_y2_output_root_mean_squared_error: 2.4677
# Epoch 31/500
# 614/614 [==============================] - 0s 145us/sample - loss: 9.0586 - y1_output_loss: 3.2433 - y2_output_loss: 5.9280 - y1_output_root_mean_squared_error: 1.7981 - y2_output_root_mean_squared_error: 2.4136 - val_loss: 16.9250 - val_y1_output_loss: 3.8701 - val_y2_output_loss: 12.4954 - val_y1_output_root_mean_squared_error: 2.0027 - val_y2_output_root_mean_squared_error: 3.5936
# Epoch 32/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.6093 - y1_output_loss: 3.9739 - y2_output_loss: 8.5756 - y1_output_root_mean_squared_error: 1.9937 - y2_output_root_mean_squared_error: 2.9384 - val_loss: 7.1077 - val_y1_output_loss: 2.3283 - val_y2_output_loss: 4.5799 - val_y1_output_root_mean_squared_error: 1.5509 - val_y2_output_root_mean_squared_error: 2.1685
# Epoch 33/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.4696 - y1_output_loss: 2.8658 - y2_output_loss: 5.5937 - y1_output_root_mean_squared_error: 1.6931 - y2_output_root_mean_squared_error: 2.3671 - val_loss: 8.0205 - val_y1_output_loss: 3.3082 - val_y2_output_loss: 4.4465 - val_y1_output_root_mean_squared_error: 1.8490 - val_y2_output_root_mean_squared_error: 2.1451
# Epoch 34/500
# 614/614 [==============================] - 0s 142us/sample - loss: 9.9771 - y1_output_loss: 3.3729 - y2_output_loss: 6.6339 - y1_output_root_mean_squared_error: 1.8327 - y2_output_root_mean_squared_error: 2.5726 - val_loss: 19.9535 - val_y1_output_loss: 6.0077 - val_y2_output_loss: 13.3073 - val_y1_output_root_mean_squared_error: 2.4947 - val_y2_output_root_mean_squared_error: 3.7054
# Epoch 35/500
# 614/614 [==============================] - 0s 146us/sample - loss: 9.7281 - y1_output_loss: 3.2962 - y2_output_loss: 6.3508 - y1_output_root_mean_squared_error: 1.8236 - y2_output_root_mean_squared_error: 2.5303 - val_loss: 8.9761 - val_y1_output_loss: 3.0165 - val_y2_output_loss: 5.6570 - val_y1_output_root_mean_squared_error: 1.7659 - val_y2_output_root_mean_squared_error: 2.4203
# Epoch 36/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.0282 - y1_output_loss: 3.1088 - y2_output_loss: 5.9532 - y1_output_root_mean_squared_error: 1.7664 - y2_output_root_mean_squared_error: 2.4306 - val_loss: 15.1140 - val_y1_output_loss: 4.2423 - val_y2_output_loss: 10.3345 - val_y1_output_root_mean_squared_error: 2.0963 - val_y2_output_root_mean_squared_error: 3.2740
# Epoch 37/500
# 614/614 [==============================] - 0s 142us/sample - loss: 9.9512 - y1_output_loss: 2.9724 - y2_output_loss: 6.9072 - y1_output_root_mean_squared_error: 1.7281 - y2_output_root_mean_squared_error: 2.6391 - val_loss: 7.1747 - val_y1_output_loss: 2.4721 - val_y2_output_loss: 4.4947 - val_y1_output_root_mean_squared_error: 1.5984 - val_y2_output_root_mean_squared_error: 2.1494
# Epoch 38/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.6026 - y1_output_loss: 2.5687 - y2_output_loss: 5.1264 - y1_output_root_mean_squared_error: 1.6023 - y2_output_root_mean_squared_error: 2.2439 - val_loss: 31.7478 - val_y1_output_loss: 9.1500 - val_y2_output_loss: 21.5272 - val_y1_output_root_mean_squared_error: 3.0779 - val_y2_output_root_mean_squared_error: 4.7196
# Epoch 39/500
# 614/614 [==============================] - 0s 147us/sample - loss: 10.5447 - y1_output_loss: 3.1462 - y2_output_loss: 7.3534 - y1_output_root_mean_squared_error: 1.7761 - y2_output_root_mean_squared_error: 2.7185 - val_loss: 7.7874 - val_y1_output_loss: 3.1084 - val_y2_output_loss: 4.4635 - val_y1_output_root_mean_squared_error: 1.7840 - val_y2_output_root_mean_squared_error: 2.1459
# Epoch 40/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.7424 - y1_output_loss: 2.8606 - y2_output_loss: 6.7927 - y1_output_root_mean_squared_error: 1.6993 - y2_output_root_mean_squared_error: 2.6182 - val_loss: 6.1980 - val_y1_output_loss: 2.1906 - val_y2_output_loss: 3.8353 - val_y1_output_root_mean_squared_error: 1.5024 - val_y2_output_root_mean_squared_error: 1.9852
# Epoch 41/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.4294 - y1_output_loss: 2.3575 - y2_output_loss: 5.0608 - y1_output_root_mean_squared_error: 1.5272 - y2_output_root_mean_squared_error: 2.2577 - val_loss: 7.0272 - val_y1_output_loss: 2.5706 - val_y2_output_loss: 4.2581 - val_y1_output_root_mean_squared_error: 1.6284 - val_y2_output_root_mean_squared_error: 2.0918
# Epoch 42/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.4633 - y1_output_loss: 2.4728 - y2_output_loss: 4.9763 - y1_output_root_mean_squared_error: 1.5691 - y2_output_root_mean_squared_error: 2.2364 - val_loss: 5.1947 - val_y1_output_loss: 1.8868 - val_y2_output_loss: 3.1351 - val_y1_output_root_mean_squared_error: 1.3958 - val_y2_output_root_mean_squared_error: 1.8018
# Epoch 43/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.2014 - y1_output_loss: 2.3054 - y2_output_loss: 4.9587 - y1_output_root_mean_squared_error: 1.5221 - y2_output_root_mean_squared_error: 2.2101 - val_loss: 7.9978 - val_y1_output_loss: 1.8376 - val_y2_output_loss: 5.9148 - val_y1_output_root_mean_squared_error: 1.3764 - val_y2_output_root_mean_squared_error: 2.4705
# Epoch 44/500
# 614/614 [==============================] - 0s 157us/sample - loss: 6.8873 - y1_output_loss: 2.1594 - y2_output_loss: 4.7343 - y1_output_root_mean_squared_error: 1.4667 - y2_output_root_mean_squared_error: 2.1763 - val_loss: 9.3573 - val_y1_output_loss: 3.1518 - val_y2_output_loss: 5.9120 - val_y1_output_root_mean_squared_error: 1.8033 - val_y2_output_root_mean_squared_error: 2.4709
# Epoch 45/500
# 614/614 [==============================] - 0s 152us/sample - loss: 7.0475 - y1_output_loss: 2.2077 - y2_output_loss: 4.8832 - y1_output_root_mean_squared_error: 1.4819 - y2_output_root_mean_squared_error: 2.2026 - val_loss: 22.3592 - val_y1_output_loss: 4.4545 - val_y2_output_loss: 17.1428 - val_y1_output_root_mean_squared_error: 2.1486 - val_y2_output_root_mean_squared_error: 4.2122
# Epoch 46/500
# 614/614 [==============================] - 0s 156us/sample - loss: 9.4333 - y1_output_loss: 2.8040 - y2_output_loss: 6.6439 - y1_output_root_mean_squared_error: 1.6688 - y2_output_root_mean_squared_error: 2.5784 - val_loss: 9.3555 - val_y1_output_loss: 2.0938 - val_y2_output_loss: 7.0236 - val_y1_output_root_mean_squared_error: 1.4627 - val_y2_output_root_mean_squared_error: 2.6862
# Epoch 47/500
# 614/614 [==============================] - 0s 172us/sample - loss: 6.9544 - y1_output_loss: 2.0737 - y2_output_loss: 4.8312 - y1_output_root_mean_squared_error: 1.4452 - y2_output_root_mean_squared_error: 2.2059 - val_loss: 12.7677 - val_y1_output_loss: 4.5387 - val_y2_output_loss: 7.8803 - val_y1_output_root_mean_squared_error: 2.1574 - val_y2_output_root_mean_squared_error: 2.8484
# Epoch 48/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.1761 - y1_output_loss: 3.0161 - y2_output_loss: 7.0712 - y1_output_root_mean_squared_error: 1.7441 - y2_output_root_mean_squared_error: 2.6710 - val_loss: 9.4180 - val_y1_output_loss: 2.7972 - val_y2_output_loss: 6.3155 - val_y1_output_root_mean_squared_error: 1.6965 - val_y2_output_root_mean_squared_error: 2.5573
# Epoch 49/500
# 614/614 [==============================] - 0s 149us/sample - loss: 8.6526 - y1_output_loss: 2.8611 - y2_output_loss: 5.8028 - y1_output_root_mean_squared_error: 1.6838 - y2_output_root_mean_squared_error: 2.4119 - val_loss: 9.6633 - val_y1_output_loss: 3.8214 - val_y2_output_loss: 5.6137 - val_y1_output_root_mean_squared_error: 1.9762 - val_y2_output_root_mean_squared_error: 2.3995
# Epoch 50/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.4980 - y1_output_loss: 3.3384 - y2_output_loss: 7.1242 - y1_output_root_mean_squared_error: 1.8307 - y2_output_root_mean_squared_error: 2.6733 - val_loss: 21.6085 - val_y1_output_loss: 3.4172 - val_y2_output_loss: 17.4506 - val_y1_output_root_mean_squared_error: 1.8814 - val_y2_output_root_mean_squared_error: 4.2508
# Epoch 51/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.9898 - y1_output_loss: 2.5531 - y2_output_loss: 6.4223 - y1_output_root_mean_squared_error: 1.6006 - y2_output_root_mean_squared_error: 2.5353 - val_loss: 4.6839 - val_y1_output_loss: 1.4604 - val_y2_output_loss: 3.0903 - val_y1_output_root_mean_squared_error: 1.2267 - val_y2_output_root_mean_squared_error: 1.7830
# Epoch 52/500
# 614/614 [==============================] - 0s 158us/sample - loss: 7.1800 - y1_output_loss: 1.9953 - y2_output_loss: 5.1784 - y1_output_root_mean_squared_error: 1.4039 - y2_output_root_mean_squared_error: 2.2823 - val_loss: 5.4075 - val_y1_output_loss: 1.7928 - val_y2_output_loss: 3.4524 - val_y1_output_root_mean_squared_error: 1.3579 - val_y2_output_root_mean_squared_error: 1.8878
# Epoch 53/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.0283 - y1_output_loss: 2.1962 - y2_output_loss: 5.7870 - y1_output_root_mean_squared_error: 1.4878 - y2_output_root_mean_squared_error: 2.4114 - val_loss: 7.0186 - val_y1_output_loss: 2.5057 - val_y2_output_loss: 4.3095 - val_y1_output_root_mean_squared_error: 1.6086 - val_y2_output_root_mean_squared_error: 2.1050
# Epoch 54/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.6067 - y1_output_loss: 1.6591 - y2_output_loss: 3.9906 - y1_output_root_mean_squared_error: 1.2854 - y2_output_root_mean_squared_error: 1.9885 - val_loss: 5.0876 - val_y1_output_loss: 1.7676 - val_y2_output_loss: 3.1755 - val_y1_output_root_mean_squared_error: 1.3469 - val_y2_output_root_mean_squared_error: 1.8093
# Epoch 55/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.1639 - y1_output_loss: 1.6364 - y2_output_loss: 4.4727 - y1_output_root_mean_squared_error: 1.2849 - y2_output_root_mean_squared_error: 2.1244 - val_loss: 3.4982 - val_y1_output_loss: 1.0593 - val_y2_output_loss: 2.3321 - val_y1_output_root_mean_squared_error: 1.0435 - val_y2_output_root_mean_squared_error: 1.5522
# Epoch 56/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.1082 - y1_output_loss: 1.7719 - y2_output_loss: 4.3133 - y1_output_root_mean_squared_error: 1.3348 - y2_output_root_mean_squared_error: 2.0800 - val_loss: 12.1566 - val_y1_output_loss: 2.3411 - val_y2_output_loss: 9.3865 - val_y1_output_root_mean_squared_error: 1.5569 - val_y2_output_root_mean_squared_error: 3.1197
# Epoch 57/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.3461 - y1_output_loss: 1.4713 - y2_output_loss: 3.8836 - y1_output_root_mean_squared_error: 1.2160 - y2_output_root_mean_squared_error: 1.9666 - val_loss: 4.3553 - val_y1_output_loss: 1.4301 - val_y2_output_loss: 2.7730 - val_y1_output_root_mean_squared_error: 1.2162 - val_y2_output_root_mean_squared_error: 1.6959
# Epoch 58/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.4353 - y1_output_loss: 1.5214 - y2_output_loss: 3.9011 - y1_output_root_mean_squared_error: 1.2327 - y2_output_root_mean_squared_error: 1.9788 - val_loss: 4.0097 - val_y1_output_loss: 1.3162 - val_y2_output_loss: 2.5931 - val_y1_output_root_mean_squared_error: 1.1604 - val_y2_output_root_mean_squared_error: 1.6319
# Epoch 59/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.2451 - y1_output_loss: 1.6158 - y2_output_loss: 3.6128 - y1_output_root_mean_squared_error: 1.2668 - y2_output_root_mean_squared_error: 1.9079 - val_loss: 4.0315 - val_y1_output_loss: 1.2010 - val_y2_output_loss: 2.7287 - val_y1_output_root_mean_squared_error: 1.1060 - val_y2_output_root_mean_squared_error: 1.6758
# Epoch 60/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.0187 - y1_output_loss: 1.6046 - y2_output_loss: 4.3985 - y1_output_root_mean_squared_error: 1.2671 - y2_output_root_mean_squared_error: 2.1008 - val_loss: 6.7772 - val_y1_output_loss: 2.3686 - val_y2_output_loss: 4.2704 - val_y1_output_root_mean_squared_error: 1.5499 - val_y2_output_root_mean_squared_error: 2.0916
# Epoch 61/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.3526 - y1_output_loss: 1.4636 - y2_output_loss: 3.9102 - y1_output_root_mean_squared_error: 1.2036 - y2_output_root_mean_squared_error: 1.9759 - val_loss: 5.2648 - val_y1_output_loss: 1.2553 - val_y2_output_loss: 3.9216 - val_y1_output_root_mean_squared_error: 1.1309 - val_y2_output_root_mean_squared_error: 1.9965
# Epoch 62/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.0780 - y1_output_loss: 1.4402 - y2_output_loss: 3.6122 - y1_output_root_mean_squared_error: 1.2039 - y2_output_root_mean_squared_error: 1.9049 - val_loss: 3.0234 - val_y1_output_loss: 0.7532 - val_y2_output_loss: 2.1717 - val_y1_output_root_mean_squared_error: 0.8805 - val_y2_output_root_mean_squared_error: 1.4994
# Epoch 63/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.0727 - y1_output_loss: 1.0649 - y2_output_loss: 2.9887 - y1_output_root_mean_squared_error: 1.0326 - y2_output_root_mean_squared_error: 1.7339 - val_loss: 3.2147 - val_y1_output_loss: 0.7798 - val_y2_output_loss: 2.3442 - val_y1_output_root_mean_squared_error: 0.8970 - val_y2_output_root_mean_squared_error: 1.5525
# Epoch 64/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.4436 - y1_output_loss: 1.0475 - y2_output_loss: 3.4230 - y1_output_root_mean_squared_error: 1.0217 - y2_output_root_mean_squared_error: 1.8438 - val_loss: 6.7333 - val_y1_output_loss: 0.8641 - val_y2_output_loss: 5.6729 - val_y1_output_root_mean_squared_error: 0.9454 - val_y2_output_root_mean_squared_error: 2.4165
# Epoch 65/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.6950 - y1_output_loss: 1.3205 - y2_output_loss: 3.3558 - y1_output_root_mean_squared_error: 1.1465 - y2_output_root_mean_squared_error: 1.8386 - val_loss: 2.8504 - val_y1_output_loss: 0.7985 - val_y2_output_loss: 1.9904 - val_y1_output_root_mean_squared_error: 0.8994 - val_y2_output_root_mean_squared_error: 1.4288
# Epoch 66/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.0333 - y1_output_loss: 1.0411 - y2_output_loss: 3.0313 - y1_output_root_mean_squared_error: 1.0220 - y2_output_root_mean_squared_error: 1.7288 - val_loss: 8.6779 - val_y1_output_loss: 1.0706 - val_y2_output_loss: 7.3094 - val_y1_output_root_mean_squared_error: 1.0528 - val_y2_output_root_mean_squared_error: 2.7513
# Epoch 67/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.9378 - y1_output_loss: 1.0351 - y2_output_loss: 2.8858 - y1_output_root_mean_squared_error: 1.0162 - y2_output_root_mean_squared_error: 1.7045 - val_loss: 3.4252 - val_y1_output_loss: 1.0176 - val_y2_output_loss: 2.3252 - val_y1_output_root_mean_squared_error: 1.0215 - val_y2_output_root_mean_squared_error: 1.5433
# Epoch 68/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.9062 - y1_output_loss: 0.9472 - y2_output_loss: 2.9568 - y1_output_root_mean_squared_error: 0.9757 - y2_output_root_mean_squared_error: 1.7188 - val_loss: 4.6182 - val_y1_output_loss: 0.9172 - val_y2_output_loss: 3.5437 - val_y1_output_root_mean_squared_error: 0.9728 - val_y2_output_root_mean_squared_error: 1.9162
# Epoch 69/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.9780 - y1_output_loss: 0.8915 - y2_output_loss: 3.1437 - y1_output_root_mean_squared_error: 0.9446 - y2_output_root_mean_squared_error: 1.7566 - val_loss: 8.8905 - val_y1_output_loss: 2.0819 - val_y2_output_loss: 6.5170 - val_y1_output_root_mean_squared_error: 1.4675 - val_y2_output_root_mean_squared_error: 2.5956
# Epoch 70/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.3605 - y1_output_loss: 1.0272 - y2_output_loss: 3.3221 - y1_output_root_mean_squared_error: 1.0179 - y2_output_root_mean_squared_error: 1.8233 - val_loss: 5.8645 - val_y1_output_loss: 1.4787 - val_y2_output_loss: 4.2052 - val_y1_output_root_mean_squared_error: 1.2332 - val_y2_output_root_mean_squared_error: 2.0842
# Epoch 71/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.5457 - y1_output_loss: 0.8330 - y2_output_loss: 2.7850 - y1_output_root_mean_squared_error: 0.9168 - y2_output_root_mean_squared_error: 1.6447 - val_loss: 21.4842 - val_y1_output_loss: 2.5464 - val_y2_output_loss: 18.2606 - val_y1_output_root_mean_squared_error: 1.6224 - val_y2_output_root_mean_squared_error: 4.3419
# Epoch 72/500
# 614/614 [==============================] - 0s 163us/sample - loss: 8.3312 - y1_output_loss: 2.2716 - y2_output_loss: 6.0237 - y1_output_root_mean_squared_error: 1.5122 - y2_output_root_mean_squared_error: 2.4586 - val_loss: 4.4112 - val_y1_output_loss: 1.1541 - val_y2_output_loss: 3.1408 - val_y1_output_root_mean_squared_error: 1.0828 - val_y2_output_root_mean_squared_error: 1.7997
# Epoch 73/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.8895 - y1_output_loss: 0.9711 - y2_output_loss: 2.8987 - y1_output_root_mean_squared_error: 0.9863 - y2_output_root_mean_squared_error: 1.7078 - val_loss: 5.4903 - val_y1_output_loss: 1.0237 - val_y2_output_loss: 4.2894 - val_y1_output_root_mean_squared_error: 1.0221 - val_y2_output_root_mean_squared_error: 2.1085
# Epoch 74/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1764 - y1_output_loss: 0.6689 - y2_output_loss: 2.4849 - y1_output_root_mean_squared_error: 0.8218 - y2_output_root_mean_squared_error: 1.5815 - val_loss: 2.6582 - val_y1_output_loss: 0.5860 - val_y2_output_loss: 2.0102 - val_y1_output_root_mean_squared_error: 0.7752 - val_y2_output_root_mean_squared_error: 1.4343
# Epoch 75/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.8854 - y1_output_loss: 1.1355 - y2_output_loss: 3.7193 - y1_output_root_mean_squared_error: 1.0682 - y2_output_root_mean_squared_error: 1.9350 - val_loss: 2.5941 - val_y1_output_loss: 0.6084 - val_y2_output_loss: 1.9227 - val_y1_output_root_mean_squared_error: 0.7823 - val_y2_output_root_mean_squared_error: 1.4079
# Epoch 76/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.5668 - y1_output_loss: 0.7641 - y2_output_loss: 2.7897 - y1_output_root_mean_squared_error: 0.8779 - y2_output_root_mean_squared_error: 1.6721 - val_loss: 2.3261 - val_y1_output_loss: 0.5267 - val_y2_output_loss: 1.7335 - val_y1_output_root_mean_squared_error: 0.7332 - val_y2_output_root_mean_squared_error: 1.3374
# Epoch 77/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.6276 - y1_output_loss: 0.6925 - y2_output_loss: 2.9151 - y1_output_root_mean_squared_error: 0.8311 - y2_output_root_mean_squared_error: 1.7137 - val_loss: 2.4304 - val_y1_output_loss: 0.6418 - val_y2_output_loss: 1.7209 - val_y1_output_root_mean_squared_error: 0.8123 - val_y2_output_root_mean_squared_error: 1.3306
# Epoch 78/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.5973 - y1_output_loss: 0.8807 - y2_output_loss: 2.6926 - y1_output_root_mean_squared_error: 0.9408 - y2_output_root_mean_squared_error: 1.6469 - val_loss: 1.9869 - val_y1_output_loss: 0.4431 - val_y2_output_loss: 1.4919 - val_y1_output_root_mean_squared_error: 0.6720 - val_y2_output_root_mean_squared_error: 1.2391
# Epoch 79/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4172 - y1_output_loss: 0.8421 - y2_output_loss: 2.6241 - y1_output_root_mean_squared_error: 0.9118 - y2_output_root_mean_squared_error: 1.6080 - val_loss: 9.2567 - val_y1_output_loss: 1.7116 - val_y2_output_loss: 7.2668 - val_y1_output_root_mean_squared_error: 1.3326 - val_y2_output_root_mean_squared_error: 2.7351
# Epoch 80/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.2290 - y1_output_loss: 0.6797 - y2_output_loss: 2.5430 - y1_output_root_mean_squared_error: 0.8251 - y2_output_root_mean_squared_error: 1.5963 - val_loss: 4.0970 - val_y1_output_loss: 1.2529 - val_y2_output_loss: 2.7880 - val_y1_output_root_mean_squared_error: 1.1274 - val_y2_output_root_mean_squared_error: 1.6811
# Epoch 81/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.9046 - y1_output_loss: 3.3450 - y2_output_loss: 6.5215 - y1_output_root_mean_squared_error: 1.8359 - y2_output_root_mean_squared_error: 2.5562 - val_loss: 5.4427 - val_y1_output_loss: 1.4725 - val_y2_output_loss: 3.7921 - val_y1_output_root_mean_squared_error: 1.2296 - val_y2_output_root_mean_squared_error: 1.9826
# Epoch 82/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.7385 - y1_output_loss: 0.6207 - y2_output_loss: 2.1270 - y1_output_root_mean_squared_error: 0.7875 - y2_output_root_mean_squared_error: 1.4555 - val_loss: 4.0344 - val_y1_output_loss: 0.5831 - val_y2_output_loss: 3.3412 - val_y1_output_root_mean_squared_error: 0.7713 - val_y2_output_root_mean_squared_error: 1.8546
# Epoch 83/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.9991 - y1_output_loss: 0.6962 - y2_output_loss: 2.4033 - y1_output_root_mean_squared_error: 0.8193 - y2_output_root_mean_squared_error: 1.5257 - val_loss: 15.4533 - val_y1_output_loss: 3.8967 - val_y2_output_loss: 11.0596 - val_y1_output_root_mean_squared_error: 2.0052 - val_y2_output_root_mean_squared_error: 3.3812
# Epoch 84/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.8357 - y1_output_loss: 1.3271 - y2_output_loss: 4.4616 - y1_output_root_mean_squared_error: 1.1545 - y2_output_root_mean_squared_error: 2.1220 - val_loss: 2.7686 - val_y1_output_loss: 0.8127 - val_y2_output_loss: 1.8753 - val_y1_output_root_mean_squared_error: 0.9146 - val_y2_output_root_mean_squared_error: 1.3900
# Epoch 85/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.3018 - y1_output_loss: 0.7206 - y2_output_loss: 2.5558 - y1_output_root_mean_squared_error: 0.8500 - y2_output_root_mean_squared_error: 1.6060 - val_loss: 2.6440 - val_y1_output_loss: 0.7694 - val_y2_output_loss: 1.8416 - val_y1_output_root_mean_squared_error: 0.8834 - val_y2_output_root_mean_squared_error: 1.3651
# Epoch 86/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.5979 - y1_output_loss: 0.5675 - y2_output_loss: 2.0323 - y1_output_root_mean_squared_error: 0.7537 - y2_output_root_mean_squared_error: 1.4247 - val_loss: 4.0244 - val_y1_output_loss: 0.5076 - val_y2_output_loss: 3.3932 - val_y1_output_root_mean_squared_error: 0.7229 - val_y2_output_root_mean_squared_error: 1.8713
# Epoch 87/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.7237 - y1_output_loss: 1.8802 - y2_output_loss: 3.8068 - y1_output_root_mean_squared_error: 1.3740 - y2_output_root_mean_squared_error: 1.9585 - val_loss: 2.1556 - val_y1_output_loss: 0.6258 - val_y2_output_loss: 1.4954 - val_y1_output_root_mean_squared_error: 0.7978 - val_y2_output_root_mean_squared_error: 1.2325
# Epoch 88/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4066 - y1_output_loss: 0.4916 - y2_output_loss: 1.9430 - y1_output_root_mean_squared_error: 0.7022 - y2_output_root_mean_squared_error: 1.3833 - val_loss: 4.3371 - val_y1_output_loss: 0.6757 - val_y2_output_loss: 3.5711 - val_y1_output_root_mean_squared_error: 0.8321 - val_y2_output_root_mean_squared_error: 1.9091
# Epoch 89/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.0647 - y1_output_loss: 0.8872 - y2_output_loss: 3.1727 - y1_output_root_mean_squared_error: 0.9429 - y2_output_root_mean_squared_error: 1.7820 - val_loss: 3.2916 - val_y1_output_loss: 0.5017 - val_y2_output_loss: 2.6879 - val_y1_output_root_mean_squared_error: 0.7186 - val_y2_output_root_mean_squared_error: 1.6659
# Epoch 90/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.6733 - y1_output_loss: 0.5220 - y2_output_loss: 2.1824 - y1_output_root_mean_squared_error: 0.7211 - y2_output_root_mean_squared_error: 1.4674 - val_loss: 6.7995 - val_y1_output_loss: 1.6566 - val_y2_output_loss: 4.9520 - val_y1_output_root_mean_squared_error: 1.3078 - val_y2_output_root_mean_squared_error: 2.2559
# Epoch 91/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.0687 - y1_output_loss: 0.6816 - y2_output_loss: 2.3910 - y1_output_root_mean_squared_error: 0.8288 - y2_output_root_mean_squared_error: 1.5433 - val_loss: 3.1664 - val_y1_output_loss: 0.5561 - val_y2_output_loss: 2.5031 - val_y1_output_root_mean_squared_error: 0.7572 - val_y2_output_root_mean_squared_error: 1.6103
# Epoch 92/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.2683 - y1_output_loss: 0.4625 - y2_output_loss: 1.8065 - y1_output_root_mean_squared_error: 0.6773 - y2_output_root_mean_squared_error: 1.3452 - val_loss: 8.5849 - val_y1_output_loss: 3.9393 - val_y2_output_loss: 4.4639 - val_y1_output_root_mean_squared_error: 2.0077 - val_y2_output_root_mean_squared_error: 2.1340
# Epoch 93/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.3959 - y1_output_loss: 0.8288 - y2_output_loss: 2.5474 - y1_output_root_mean_squared_error: 0.9132 - y2_output_root_mean_squared_error: 1.6006 - val_loss: 1.9473 - val_y1_output_loss: 0.4487 - val_y2_output_loss: 1.4429 - val_y1_output_root_mean_squared_error: 0.6784 - val_y2_output_root_mean_squared_error: 1.2194
# Epoch 94/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.0082 - y1_output_loss: 0.6023 - y2_output_loss: 2.4139 - y1_output_root_mean_squared_error: 0.7754 - y2_output_root_mean_squared_error: 1.5515 - val_loss: 4.4229 - val_y1_output_loss: 0.5378 - val_y2_output_loss: 3.7366 - val_y1_output_root_mean_squared_error: 0.7423 - val_y2_output_root_mean_squared_error: 1.9677
# Epoch 95/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.2012 - y1_output_loss: 0.4498 - y2_output_loss: 1.7509 - y1_output_root_mean_squared_error: 0.6706 - y2_output_root_mean_squared_error: 1.3234 - val_loss: 2.9082 - val_y1_output_loss: 0.6046 - val_y2_output_loss: 2.2341 - val_y1_output_root_mean_squared_error: 0.7892 - val_y2_output_root_mean_squared_error: 1.5117
# Epoch 96/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.3675 - y1_output_loss: 0.5188 - y2_output_loss: 1.8725 - y1_output_root_mean_squared_error: 0.7141 - y2_output_root_mean_squared_error: 1.3629 - val_loss: 8.2980 - val_y1_output_loss: 2.1870 - val_y2_output_loss: 5.9340 - val_y1_output_root_mean_squared_error: 1.4981 - val_y2_output_root_mean_squared_error: 2.4604
# Epoch 97/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.1142 - y1_output_loss: 0.6815 - y2_output_loss: 2.6553 - y1_output_root_mean_squared_error: 0.7785 - y2_output_root_mean_squared_error: 1.5837 - val_loss: 78.8244 - val_y1_output_loss: 34.5041 - val_y2_output_loss: 42.3550 - val_y1_output_root_mean_squared_error: 5.9525 - val_y2_output_root_mean_squared_error: 6.5873
# Epoch 98/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.2627 - y1_output_loss: 1.6214 - y2_output_loss: 3.6365 - y1_output_root_mean_squared_error: 1.2787 - y2_output_root_mean_squared_error: 1.9046 - val_loss: 2.5540 - val_y1_output_loss: 0.5360 - val_y2_output_loss: 1.9703 - val_y1_output_root_mean_squared_error: 0.7363 - val_y2_output_root_mean_squared_error: 1.4184
# Epoch 99/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.4412 - y1_output_loss: 0.4894 - y2_output_loss: 1.9735 - y1_output_root_mean_squared_error: 0.7006 - y2_output_root_mean_squared_error: 1.3965 - val_loss: 2.1830 - val_y1_output_loss: 0.5952 - val_y2_output_loss: 1.5642 - val_y1_output_root_mean_squared_error: 0.7777 - val_y2_output_root_mean_squared_error: 1.2563
# Epoch 100/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.2723 - y1_output_loss: 0.4321 - y2_output_loss: 1.8194 - y1_output_root_mean_squared_error: 0.6599 - y2_output_root_mean_squared_error: 1.3553 - val_loss: 1.8520 - val_y1_output_loss: 0.5631 - val_y2_output_loss: 1.2410 - val_y1_output_root_mean_squared_error: 0.7584 - val_y2_output_root_mean_squared_error: 1.1300
# Epoch 101/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.3617 - y1_output_loss: 0.4841 - y2_output_loss: 1.8691 - y1_output_root_mean_squared_error: 0.6986 - y2_output_root_mean_squared_error: 1.3688 - val_loss: 1.6506 - val_y1_output_loss: 0.4228 - val_y2_output_loss: 1.1819 - val_y1_output_root_mean_squared_error: 0.6592 - val_y2_output_root_mean_squared_error: 1.1028
# Epoch 102/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.2588 - y1_output_loss: 0.7034 - y2_output_loss: 2.5702 - y1_output_root_mean_squared_error: 0.8406 - y2_output_root_mean_squared_error: 1.5975 - val_loss: 4.8807 - val_y1_output_loss: 1.7715 - val_y2_output_loss: 3.1364 - val_y1_output_root_mean_squared_error: 1.3288 - val_y2_output_root_mean_squared_error: 1.7649
# Epoch 103/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.1927 - y1_output_loss: 0.4671 - y2_output_loss: 1.7299 - y1_output_root_mean_squared_error: 0.6866 - y2_output_root_mean_squared_error: 1.3120 - val_loss: 3.7101 - val_y1_output_loss: 0.8218 - val_y2_output_loss: 2.7621 - val_y1_output_root_mean_squared_error: 0.9219 - val_y2_output_root_mean_squared_error: 1.6912
# Epoch 104/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9570 - y1_output_loss: 0.5853 - y2_output_loss: 2.3646 - y1_output_root_mean_squared_error: 0.7648 - y2_output_root_mean_squared_error: 1.5401 - val_loss: 2.1514 - val_y1_output_loss: 0.7394 - val_y2_output_loss: 1.3525 - val_y1_output_root_mean_squared_error: 0.8690 - val_y2_output_root_mean_squared_error: 1.1816
# Epoch 105/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.0149 - y1_output_loss: 0.4875 - y2_output_loss: 1.5483 - y1_output_root_mean_squared_error: 0.6984 - y2_output_root_mean_squared_error: 1.2358 - val_loss: 8.8317 - val_y1_output_loss: 1.5194 - val_y2_output_loss: 6.9994 - val_y1_output_root_mean_squared_error: 1.2536 - val_y2_output_root_mean_squared_error: 2.6945
# Epoch 106/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3886 - y1_output_loss: 0.5240 - y2_output_loss: 1.9107 - y1_output_root_mean_squared_error: 0.7196 - y2_output_root_mean_squared_error: 1.3678 - val_loss: 11.1417 - val_y1_output_loss: 1.6314 - val_y2_output_loss: 9.1407 - val_y1_output_root_mean_squared_error: 1.3007 - val_y2_output_root_mean_squared_error: 3.0741
# Epoch 107/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.8411 - y1_output_loss: 0.9155 - y2_output_loss: 2.9179 - y1_output_root_mean_squared_error: 0.9594 - y2_output_root_mean_squared_error: 1.7090 - val_loss: 2.8017 - val_y1_output_loss: 0.6628 - val_y2_output_loss: 2.0521 - val_y1_output_root_mean_squared_error: 0.8262 - val_y2_output_root_mean_squared_error: 1.4557
# Epoch 108/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.3350 - y1_output_loss: 0.4851 - y2_output_loss: 1.8431 - y1_output_root_mean_squared_error: 0.6987 - y2_output_root_mean_squared_error: 1.3590 - val_loss: 1.6032 - val_y1_output_loss: 0.3798 - val_y2_output_loss: 1.1692 - val_y1_output_root_mean_squared_error: 0.6260 - val_y2_output_root_mean_squared_error: 1.1006
# Epoch 109/500
# 614/614 [==============================] - 0s 142us/sample - loss: 1.9719 - y1_output_loss: 0.3907 - y2_output_loss: 1.5801 - y1_output_root_mean_squared_error: 0.6264 - y2_output_root_mean_squared_error: 1.2568 - val_loss: 1.6496 - val_y1_output_loss: 0.4125 - val_y2_output_loss: 1.1904 - val_y1_output_root_mean_squared_error: 0.6521 - val_y2_output_root_mean_squared_error: 1.1065
# Epoch 110/500
# 614/614 [==============================] - 0s 142us/sample - loss: 1.9646 - y1_output_loss: 0.3965 - y2_output_loss: 1.5512 - y1_output_root_mean_squared_error: 0.6321 - y2_output_root_mean_squared_error: 1.2510 - val_loss: 4.3432 - val_y1_output_loss: 1.8062 - val_y2_output_loss: 2.3954 - val_y1_output_root_mean_squared_error: 1.3675 - val_y2_output_root_mean_squared_error: 1.5726
# Epoch 111/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.1799 - y1_output_loss: 0.4810 - y2_output_loss: 1.6825 - y1_output_root_mean_squared_error: 0.6959 - y2_output_root_mean_squared_error: 1.3021 - val_loss: 2.1709 - val_y1_output_loss: 0.7234 - val_y2_output_loss: 1.3846 - val_y1_output_root_mean_squared_error: 0.8658 - val_y2_output_root_mean_squared_error: 1.1922
# Epoch 112/500
# 614/614 [==============================] - 0s 143us/sample - loss: 1.8203 - y1_output_loss: 0.3681 - y2_output_loss: 1.4552 - y1_output_root_mean_squared_error: 0.6080 - y2_output_root_mean_squared_error: 1.2044 - val_loss: 2.1465 - val_y1_output_loss: 0.3876 - val_y2_output_loss: 1.7063 - val_y1_output_root_mean_squared_error: 0.6324 - val_y2_output_root_mean_squared_error: 1.3216
# Epoch 113/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.9498 - y1_output_loss: 0.3938 - y2_output_loss: 1.5630 - y1_output_root_mean_squared_error: 0.6275 - y2_output_root_mean_squared_error: 1.2475 - val_loss: 3.2977 - val_y1_output_loss: 0.4183 - val_y2_output_loss: 2.7720 - val_y1_output_root_mean_squared_error: 0.6543 - val_y2_output_root_mean_squared_error: 1.6940
# Epoch 114/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.3267 - y1_output_loss: 0.4956 - y2_output_loss: 1.8419 - y1_output_root_mean_squared_error: 0.7007 - y2_output_root_mean_squared_error: 1.3549 - val_loss: 5.4292 - val_y1_output_loss: 1.3969 - val_y2_output_loss: 3.8759 - val_y1_output_root_mean_squared_error: 1.2014 - val_y2_output_root_mean_squared_error: 1.9964
# Epoch 115/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.0254 - y1_output_loss: 0.4406 - y2_output_loss: 1.5675 - y1_output_root_mean_squared_error: 0.6661 - y2_output_root_mean_squared_error: 1.2577 - val_loss: 1.8398 - val_y1_output_loss: 0.4507 - val_y2_output_loss: 1.3312 - val_y1_output_root_mean_squared_error: 0.6827 - val_y2_output_root_mean_squared_error: 1.1721
# Epoch 116/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3070 - y1_output_loss: 0.4986 - y2_output_loss: 1.7899 - y1_output_root_mean_squared_error: 0.7085 - y2_output_root_mean_squared_error: 1.3435 - val_loss: 1.4758 - val_y1_output_loss: 0.4323 - val_y2_output_loss: 1.0010 - val_y1_output_root_mean_squared_error: 0.6640 - val_y2_output_root_mean_squared_error: 1.0173
# Epoch 117/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.4586 - y1_output_loss: 0.4602 - y2_output_loss: 1.9876 - y1_output_root_mean_squared_error: 0.6787 - y2_output_root_mean_squared_error: 1.4135 - val_loss: 2.0648 - val_y1_output_loss: 0.5217 - val_y2_output_loss: 1.4849 - val_y1_output_root_mean_squared_error: 0.7324 - val_y2_output_root_mean_squared_error: 1.2363
# Epoch 118/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.5832 - y1_output_loss: 0.5898 - y2_output_loss: 1.9784 - y1_output_root_mean_squared_error: 0.7713 - y2_output_root_mean_squared_error: 1.4101 - val_loss: 3.1788 - val_y1_output_loss: 0.5741 - val_y2_output_loss: 2.4982 - val_y1_output_root_mean_squared_error: 0.7707 - val_y2_output_root_mean_squared_error: 1.6078
# Epoch 119/500
# 614/614 [==============================] - 0s 145us/sample - loss: 1.9021 - y1_output_loss: 0.3955 - y2_output_loss: 1.5001 - y1_output_root_mean_squared_error: 0.6317 - y2_output_root_mean_squared_error: 1.2260 - val_loss: 1.9084 - val_y1_output_loss: 0.4747 - val_y2_output_loss: 1.3849 - val_y1_output_root_mean_squared_error: 0.7006 - val_y2_output_root_mean_squared_error: 1.1906
# Epoch 120/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.8504 - y1_output_loss: 0.4421 - y2_output_loss: 1.3913 - y1_output_root_mean_squared_error: 0.6679 - y2_output_root_mean_squared_error: 1.1850 - val_loss: 1.5804 - val_y1_output_loss: 0.3982 - val_y2_output_loss: 1.1274 - val_y1_output_root_mean_squared_error: 0.6422 - val_y2_output_root_mean_squared_error: 1.0807
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3340 - y1_output_loss: 0.1079 - y2_output_loss: 0.2270 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.4769 - val_loss: 0.7580 - val_y1_output_loss: 0.2222 - val_y2_output_loss: 0.5266 - val_y1_output_root_mean_squared_error: 0.4749 - val_y2_output_root_mean_squared_error: 0.7297
# Epoch 462/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.3113 - y1_output_loss: 0.0949 - y2_output_loss: 0.2142 - y1_output_root_mean_squared_error: 0.3093 - y2_output_root_mean_squared_error: 0.4644 - val_loss: 0.6772 - val_y1_output_loss: 0.1926 - val_y2_output_loss: 0.4765 - val_y1_output_root_mean_squared_error: 0.4389 - val_y2_output_root_mean_squared_error: 0.6961
# Epoch 463/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3046 - y1_output_loss: 0.1057 - y2_output_loss: 0.1986 - y1_output_root_mean_squared_error: 0.3258 - y2_output_root_mean_squared_error: 0.4455 - val_loss: 0.9499 - val_y1_output_loss: 0.3122 - val_y2_output_loss: 0.6187 - val_y1_output_root_mean_squared_error: 0.5655 - val_y2_output_root_mean_squared_error: 0.7938
# Epoch 464/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3537 - y1_output_loss: 0.1054 - y2_output_loss: 0.2459 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.4975 - val_loss: 0.6452 - val_y1_output_loss: 0.2144 - val_y2_output_loss: 0.4171 - val_y1_output_root_mean_squared_error: 0.4670 - val_y2_output_root_mean_squared_error: 0.6536
# Epoch 465/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2862 - y1_output_loss: 0.0948 - y2_output_loss: 0.1894 - y1_output_root_mean_squared_error: 0.3083 - y2_output_root_mean_squared_error: 0.4372 - val_loss: 0.6689 - val_y1_output_loss: 0.2175 - val_y2_output_loss: 0.4454 - val_y1_output_root_mean_squared_error: 0.4689 - val_y2_output_root_mean_squared_error: 0.6701
# Epoch 466/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3410 - y1_output_loss: 0.1002 - y2_output_loss: 0.2382 - y1_output_root_mean_squared_error: 0.3174 - y2_output_root_mean_squared_error: 0.4902 - val_loss: 0.7357 - val_y1_output_loss: 0.1932 - val_y2_output_loss: 0.5527 - val_y1_output_root_mean_squared_error: 0.4321 - val_y2_output_root_mean_squared_error: 0.7410
# Epoch 467/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3402 - y1_output_loss: 0.1057 - y2_output_loss: 0.2363 - y1_output_root_mean_squared_error: 0.3226 - y2_output_root_mean_squared_error: 0.4860 - val_loss: 0.7387 - val_y1_output_loss: 0.2086 - val_y2_output_loss: 0.5245 - val_y1_output_root_mean_squared_error: 0.4572 - val_y2_output_root_mean_squared_error: 0.7278
# Epoch 468/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3565 - y1_output_loss: 0.1143 - y2_output_loss: 0.2395 - y1_output_root_mean_squared_error: 0.3390 - y2_output_root_mean_squared_error: 0.4915 - val_loss: 0.8220 - val_y1_output_loss: 0.2627 - val_y2_output_loss: 0.5511 - val_y1_output_root_mean_squared_error: 0.5164 - val_y2_output_root_mean_squared_error: 0.7451
# Epoch 469/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5781 - y1_output_loss: 0.1507 - y2_output_loss: 0.4235 - y1_output_root_mean_squared_error: 0.3887 - y2_output_root_mean_squared_error: 0.6534 - val_loss: 0.6951 - val_y1_output_loss: 0.2464 - val_y2_output_loss: 0.4543 - val_y1_output_root_mean_squared_error: 0.4938 - val_y2_output_root_mean_squared_error: 0.6718
# Epoch 470/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.6803 - y1_output_loss: 0.1545 - y2_output_loss: 0.5219 - y1_output_root_mean_squared_error: 0.3943 - y2_output_root_mean_squared_error: 0.7245 - val_loss: 0.6570 - val_y1_output_loss: 0.2209 - val_y2_output_loss: 0.4316 - val_y1_output_root_mean_squared_error: 0.4661 - val_y2_output_root_mean_squared_error: 0.6631
# Epoch 471/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3757 - y1_output_loss: 0.1063 - y2_output_loss: 0.2673 - y1_output_root_mean_squared_error: 0.3272 - y2_output_root_mean_squared_error: 0.5183 - val_loss: 0.7697 - val_y1_output_loss: 0.2008 - val_y2_output_loss: 0.5606 - val_y1_output_root_mean_squared_error: 0.4467 - val_y2_output_root_mean_squared_error: 0.7551
# Epoch 472/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2757 - y1_output_loss: 0.0961 - y2_output_loss: 0.1795 - y1_output_root_mean_squared_error: 0.3107 - y2_output_root_mean_squared_error: 0.4232 - val_loss: 0.7421 - val_y1_output_loss: 0.2999 - val_y2_output_loss: 0.4307 - val_y1_output_root_mean_squared_error: 0.5533 - val_y2_output_root_mean_squared_error: 0.6603
# Epoch 473/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3639 - y1_output_loss: 0.1172 - y2_output_loss: 0.2440 - y1_output_root_mean_squared_error: 0.3435 - y2_output_root_mean_squared_error: 0.4959 - val_loss: 0.5892 - val_y1_output_loss: 0.2227 - val_y2_output_loss: 0.3600 - val_y1_output_root_mean_squared_error: 0.4727 - val_y2_output_root_mean_squared_error: 0.6048
# Epoch 474/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3076 - y1_output_loss: 0.1017 - y2_output_loss: 0.2051 - y1_output_root_mean_squared_error: 0.3193 - y2_output_root_mean_squared_error: 0.4535 - val_loss: 0.8031 - val_y1_output_loss: 0.2269 - val_y2_output_loss: 0.5665 - val_y1_output_root_mean_squared_error: 0.4782 - val_y2_output_root_mean_squared_error: 0.7579
# Epoch 475/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5658 - y1_output_loss: 0.1727 - y2_output_loss: 0.3889 - y1_output_root_mean_squared_error: 0.4169 - y2_output_root_mean_squared_error: 0.6261 - val_loss: 0.7515 - val_y1_output_loss: 0.2136 - val_y2_output_loss: 0.5228 - val_y1_output_root_mean_squared_error: 0.4658 - val_y2_output_root_mean_squared_error: 0.7311
# Epoch 476/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3077 - y1_output_loss: 0.1063 - y2_output_loss: 0.2056 - y1_output_root_mean_squared_error: 0.3273 - y2_output_root_mean_squared_error: 0.4479 - val_loss: 0.8369 - val_y1_output_loss: 0.2224 - val_y2_output_loss: 0.6045 - val_y1_output_root_mean_squared_error: 0.4696 - val_y2_output_root_mean_squared_error: 0.7851
# Epoch 477/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4183 - y1_output_loss: 0.1218 - y2_output_loss: 0.2936 - y1_output_root_mean_squared_error: 0.3500 - y2_output_root_mean_squared_error: 0.5439 - val_loss: 0.7883 - val_y1_output_loss: 0.2324 - val_y2_output_loss: 0.5522 - val_y1_output_root_mean_squared_error: 0.4845 - val_y2_output_root_mean_squared_error: 0.7440
# Epoch 478/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3057 - y1_output_loss: 0.0976 - y2_output_loss: 0.2073 - y1_output_root_mean_squared_error: 0.3137 - y2_output_root_mean_squared_error: 0.4553 - val_loss: 0.7269 - val_y1_output_loss: 0.2159 - val_y2_output_loss: 0.5077 - val_y1_output_root_mean_squared_error: 0.4660 - val_y2_output_root_mean_squared_error: 0.7140
# Epoch 479/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3162 - y1_output_loss: 0.1010 - y2_output_loss: 0.2133 - y1_output_root_mean_squared_error: 0.3194 - y2_output_root_mean_squared_error: 0.4628 - val_loss: 0.6874 - val_y1_output_loss: 0.2212 - val_y2_output_loss: 0.4735 - val_y1_output_root_mean_squared_error: 0.4636 - val_y2_output_root_mean_squared_error: 0.6874
# Epoch 480/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3482 - y1_output_loss: 0.1244 - y2_output_loss: 0.2236 - y1_output_root_mean_squared_error: 0.3534 - y2_output_root_mean_squared_error: 0.4726 - val_loss: 0.6463 - val_y1_output_loss: 0.1925 - val_y2_output_loss: 0.4579 - val_y1_output_root_mean_squared_error: 0.4345 - val_y2_output_root_mean_squared_error: 0.6764
# Epoch 481/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5957 - y1_output_loss: 0.1466 - y2_output_loss: 0.4453 - y1_output_root_mean_squared_error: 0.3833 - y2_output_root_mean_squared_error: 0.6699 - val_loss: 0.6205 - val_y1_output_loss: 0.2014 - val_y2_output_loss: 0.4225 - val_y1_output_root_mean_squared_error: 0.4452 - val_y2_output_root_mean_squared_error: 0.6498
# Epoch 482/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3836 - y1_output_loss: 0.1142 - y2_output_loss: 0.2682 - y1_output_root_mean_squared_error: 0.3383 - y2_output_root_mean_squared_error: 0.5188 - val_loss: 0.7359 - val_y1_output_loss: 0.2841 - val_y2_output_loss: 0.4383 - val_y1_output_root_mean_squared_error: 0.5378 - val_y2_output_root_mean_squared_error: 0.6683
# Epoch 483/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4819 - y1_output_loss: 0.1301 - y2_output_loss: 0.3484 - y1_output_root_mean_squared_error: 0.3620 - y2_output_root_mean_squared_error: 0.5923 - val_loss: 0.6766 - val_y1_output_loss: 0.1971 - val_y2_output_loss: 0.4787 - val_y1_output_root_mean_squared_error: 0.4419 - val_y2_output_root_mean_squared_error: 0.6938
# Epoch 484/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4437 - y1_output_loss: 0.1279 - y2_output_loss: 0.3122 - y1_output_root_mean_squared_error: 0.3590 - y2_output_root_mean_squared_error: 0.5610 - val_loss: 0.8754 - val_y1_output_loss: 0.3500 - val_y2_output_loss: 0.5148 - val_y1_output_root_mean_squared_error: 0.5986 - val_y2_output_root_mean_squared_error: 0.7191
# Epoch 485/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2896 - y1_output_loss: 0.1067 - y2_output_loss: 0.1812 - y1_output_root_mean_squared_error: 0.3272 - y2_output_root_mean_squared_error: 0.4273 - val_loss: 0.6394 - val_y1_output_loss: 0.2098 - val_y2_output_loss: 0.4264 - val_y1_output_root_mean_squared_error: 0.4583 - val_y2_output_root_mean_squared_error: 0.6552
# Epoch 486/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.2684 - y1_output_loss: 0.0965 - y2_output_loss: 0.1782 - y1_output_root_mean_squared_error: 0.3111 - y2_output_root_mean_squared_error: 0.4143 - val_loss: 1.6600 - val_y1_output_loss: 0.2136 - val_y2_output_loss: 1.4243 - val_y1_output_root_mean_squared_error: 0.4624 - val_y2_output_root_mean_squared_error: 1.2026
# Epoch 487/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3333 - y1_output_loss: 0.1071 - y2_output_loss: 0.2278 - y1_output_root_mean_squared_error: 0.3267 - y2_output_root_mean_squared_error: 0.4760 - val_loss: 1.1806 - val_y1_output_loss: 0.2143 - val_y2_output_loss: 0.9568 - val_y1_output_root_mean_squared_error: 0.4579 - val_y2_output_root_mean_squared_error: 0.9853
# Epoch 488/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.2916 - y1_output_loss: 0.1062 - y2_output_loss: 0.1845 - y1_output_root_mean_squared_error: 0.3265 - y2_output_root_mean_squared_error: 0.4302 - val_loss: 0.7716 - val_y1_output_loss: 0.2275 - val_y2_output_loss: 0.5334 - val_y1_output_root_mean_squared_error: 0.4793 - val_y2_output_root_mean_squared_error: 0.7361
# Epoch 489/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.2890 - y1_output_loss: 0.0925 - y2_output_loss: 0.1950 - y1_output_root_mean_squared_error: 0.3054 - y2_output_root_mean_squared_error: 0.4425 - val_loss: 0.5893 - val_y1_output_loss: 0.1973 - val_y2_output_loss: 0.3910 - val_y1_output_root_mean_squared_error: 0.4429 - val_y2_output_root_mean_squared_error: 0.6270
# Epoch 490/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3325 - y1_output_loss: 0.1022 - y2_output_loss: 0.2291 - y1_output_root_mean_squared_error: 0.3205 - y2_output_root_mean_squared_error: 0.4794 - val_loss: 0.7074 - val_y1_output_loss: 0.2344 - val_y2_output_loss: 0.4549 - val_y1_output_root_mean_squared_error: 0.4898 - val_y2_output_root_mean_squared_error: 0.6837
# Epoch 491/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2579 - y1_output_loss: 0.0955 - y2_output_loss: 0.1621 - y1_output_root_mean_squared_error: 0.3103 - y2_output_root_mean_squared_error: 0.4020 - val_loss: 0.7470 - val_y1_output_loss: 0.2441 - val_y2_output_loss: 0.4959 - val_y1_output_root_mean_squared_error: 0.4962 - val_y2_output_root_mean_squared_error: 0.7076
# Epoch 492/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.4231 - y1_output_loss: 0.1289 - y2_output_loss: 0.2921 - y1_output_root_mean_squared_error: 0.3604 - y2_output_root_mean_squared_error: 0.5415 - val_loss: 0.6063 - val_y1_output_loss: 0.1906 - val_y2_output_loss: 0.4104 - val_y1_output_root_mean_squared_error: 0.4364 - val_y2_output_root_mean_squared_error: 0.6449
# Epoch 493/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2938 - y1_output_loss: 0.1061 - y2_output_loss: 0.1984 - y1_output_root_mean_squared_error: 0.3152 - y2_output_root_mean_squared_error: 0.4409 - val_loss: 3.7826 - val_y1_output_loss: 1.9848 - val_y2_output_loss: 1.6753 - val_y1_output_root_mean_squared_error: 1.4335 - val_y2_output_root_mean_squared_error: 1.3144
# Epoch 494/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3351 - y1_output_loss: 0.1348 - y2_output_loss: 0.2016 - y1_output_root_mean_squared_error: 0.3684 - y2_output_root_mean_squared_error: 0.4465 - val_loss: 0.8625 - val_y1_output_loss: 0.1992 - val_y2_output_loss: 0.6630 - val_y1_output_root_mean_squared_error: 0.4470 - val_y2_output_root_mean_squared_error: 0.8141
# Epoch 495/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3715 - y1_output_loss: 0.1331 - y2_output_loss: 0.2360 - y1_output_root_mean_squared_error: 0.3657 - y2_output_root_mean_squared_error: 0.4876 - val_loss: 0.6899 - val_y1_output_loss: 0.2159 - val_y2_output_loss: 0.4688 - val_y1_output_root_mean_squared_error: 0.4680 - val_y2_output_root_mean_squared_error: 0.6862
# Epoch 496/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3683 - y1_output_loss: 0.1022 - y2_output_loss: 0.2671 - y1_output_root_mean_squared_error: 0.3197 - y2_output_root_mean_squared_error: 0.5159 - val_loss: 0.8106 - val_y1_output_loss: 0.2170 - val_y2_output_loss: 0.5793 - val_y1_output_root_mean_squared_error: 0.4664 - val_y2_output_root_mean_squared_error: 0.7702
# Epoch 497/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3835 - y1_output_loss: 0.1120 - y2_output_loss: 0.2695 - y1_output_root_mean_squared_error: 0.3351 - y2_output_root_mean_squared_error: 0.5208 - val_loss: 0.5985 - val_y1_output_loss: 0.2073 - val_y2_output_loss: 0.3865 - val_y1_output_root_mean_squared_error: 0.4567 - val_y2_output_root_mean_squared_error: 0.6245
# Epoch 498/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3327 - y1_output_loss: 0.1083 - y2_output_loss: 0.2304 - y1_output_root_mean_squared_error: 0.3274 - y2_output_root_mean_squared_error: 0.4749 - val_loss: 1.1038 - val_y1_output_loss: 0.3485 - val_y2_output_loss: 0.7548 - val_y1_output_root_mean_squared_error: 0.5865 - val_y2_output_root_mean_squared_error: 0.8717
# Epoch 499/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3644 - y1_output_loss: 0.0948 - y2_output_loss: 0.2675 - y1_output_root_mean_squared_error: 0.3085 - y2_output_root_mean_squared_error: 0.5189 - val_loss: 0.6327 - val_y1_output_loss: 0.1991 - val_y2_output_loss: 0.4305 - val_y1_output_root_mean_squared_error: 0.4457 - val_y2_output_root_mean_squared_error: 0.6588
# Epoch 500/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2962 - y1_output_loss: 0.0901 - y2_output_loss: 0.2045 - y1_output_root_mean_squared_error: 0.3010 - y2_output_root_mean_squared_error: 0.4535 - val_loss: 0.6337 - val_y1_output_loss: 0.2033 - val_y2_output_loss: 0.4244 - val_y1_output_root_mean_squared_error: 0.4514 - val_y2_output_root_mean_squared_error: 0.6557

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 41us/sample - loss: 0.6337 - y1_output_loss: 0.2023 - y2_output_loss: 0.4305 - y1_output_root_mean_squared_error: 0.4514 - y2_output_root_mean_squared_error: 0.6557
# Loss = 0.6337423518106535, Y1_loss = 0.20230522751808167, Y1_mse = 0.4514489471912384, Y2_loss = 0.43046122789382935, Y2_mse = 0.6556951999664307

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
